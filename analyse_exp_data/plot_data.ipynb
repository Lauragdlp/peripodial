# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Load the DataFrame from the CSV file
F3_WP = pd.read_csv('../experimental_data/F3_WP.csv')

# %%
F3_WP
# Out:
#     Unnamed: 0       area  perimeter  nb_neighbor     aniso
# 0            1  16.891191  17.409024          6.0  2.167673
# 1            2  15.159946  15.894686          4.0  2.353269
# 2            3  26.283102  21.763150          7.0  2.072801
# 3            4  19.986413  19.570081          6.0  2.304012
# 4            5  16.299923  18.513616          6.0  2.712600
# ..         ...        ...        ...          ...       ...
# 69          71  11.319396  14.440560          5.0  2.273787
# 70          72  11.564885  14.885142          3.0  3.044789
# 71          73   3.543015   7.191056          4.0  1.871961
# 72          74  15.021287  16.429453          5.0  2.214894
# 73          75  21.561037  18.543534          5.0  1.939481
#
# [74 rows x 5 columns]

# %%
F3_WP.area.min()
# Out:
# 1.0742751451292387

# %%
F3_WP.index
# Out:
# RangeIndex(start=0, stop=74, step=1)

# %%
plt.hist(F3_WP.area, bins='auto')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
conditions = ["0h", "2.5h ctrl", "2.5h agar", "5h ctrl", "5h agar"]
values_areas = {
    "0h": [],  
    "2.5h ctrl": [],
    "2.5h agar": [],
    "5h ctrl": [],
    "5h agar": [], 
}

values_areas["0h"].extend(F3_WP.area.to_list())

# %%
for condition in conditions:
    plt.scatter([condition] * len(values_areas[condition]), values_areas[condition], label=condition)

# Ajouter des légendes et des titres
plt.xlabel("Condition")
plt.ylabel("Area")
plt.title("Aire des cellules en fonction de la contrainte et du developpement")
plt.legend()
plt.savefig('../analyse_exp_data/Figures/Area_cell_IV.png', transparent=True)
# Afficher le nuage de points
plt.show()

# %%
values_aniso = {
    "0h": [],  
    "2.5h ctrl": [],
    "2.5h agar": [],
    "5h ctrl": [],
    "5h agar": [], 
}

values_aniso["0h"].extend(F3_WP.aniso)

# %%
for condition in conditions:
    plt.scatter([condition] * len(values_aniso[condition]), values_aniso[condition], label=condition)

# Ajouter des légendes et des titres
plt.xlabel("Condition")
plt.ylabel("Anisotropie")
plt.title("Anisotropie des cellules en fonction de la contrainte et du developement")
plt.legend()
plt.savefig('../analyse_exp_data/Figures/Aniso_cell_IV.png', transparent=True)
# Afficher le nuage de points
plt.show()

# %%
values_perimeter = {
    "0h": [],  
    "2.5h ctrl": [],
    "2.5h agar": [],
    "5h ctrl": [],
    "5h agar": [], 
}

values_perimeter["0h"].extend(F3_WP.perimeter)
values_perimeter["2.5h ctrl"].extend(F3_WP.perimeter)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Supposons que conditions soit une liste de différentes conditions
# Supposons que values_aniso soit un dictionnaire contenant les valeurs d'anisotropie pour chaque condition

# Création de la figure
fig = plt.figure(figsize=(20, 10))

# Tracer les boîtes à moustaches pour chaque condition
sns.boxplot(data=[values_aniso[condition] for condition in conditions],
            palette="colorblind",  # Utilisation de la palette colorblind
            order=[1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4],
            showfliers=False)

# Ajouter des légendes et des titres
plt.xlabel("Condition")
plt.ylabel("Anisotropie")
plt.title("Anisotropie des cellules en fonction de la contrainte")

# Afficher le graphique
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[27], line 11
#       8 fig = plt.figure(figsize=(20, 10))
#      10 # Tracer les boîtes à moustaches pour chaque condition
# ---> 11 sns.boxplot(data=[values_aniso[condition] for condition in conditions],
#      12             palette="colorblind",  # Utilisation de la palette colorblind
#      13             order=[1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4],
#      14             showfliers=False)
#      16 # Ajouter des légendes et des titres
#      17 plt.xlabel("Condition")
#
# File ~/miniforge3/envs/tyssue/lib/python3.10/site-packages/seaborn/categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
# ...

# %%
import seaborn as sns

plt.boxplot([values_perimeter[condition] for condition in conditions], labels=conditions, patch_artist=True)

fig = plt.figure(figsize=(20, 10))

# Tracer les boîtes à moustaches pour chaque condition
for condition in conditions:
    sns.boxplot(x=[condition] * len(values_aniso[condition]), y=values_aniso[condition], 
                palette="colorblind",
                showfliers=False)
# Ajouter des légendes et des titres
plt.xlabel("Condition")
plt.ylabel("Perimeter")
plt.title("¨Perimètre des cellules en fonction de la contrainte et du developement")
plt.legend()
plt.savefig('../analyse_exp_data/Figures/Peri_cell_IV.png', transparent=True)

# Afficher le nuage de points
plt.show()
# Out:
# /tmp/ipykernel_219291/3040752210.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=[condition] * len(values_aniso[condition]), y=values_aniso[condition],
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
